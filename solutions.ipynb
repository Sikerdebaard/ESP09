# %%
# !pip install pyreadstat openpyxl pandas jupyter statsmodels scikit-learn
# Out:
# ...
#      |████████████████████████████████| 245kB 7.1MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Day 1 solutions

# %%
from pathlib import Path


def convert(df_data, filename):
    outdir = 'converted'
    fname = Path(filename).stem
    partial = f'{outdir}/{fname}'
    df_data.to_csv(f'{partial}.csv')
    df_data.to_excel(f'{partial}.xlsx')
    #df_data.to_spss(f'{partial}.sav')
    df_data.to_stata(f'{partial}.dta')
    

for file in Path('data').glob('*.DAT'):
    df_convert = pd.read_csv(file, sep='\t')
    df_convert.set_index(df_convert.columns[0], inplace=True)
    convert(df_convert, file)

# %%
import pandas as pd


filename = 'data/EX0502.DAT'
df_data = pd.read_csv(filename, sep='\t').set_index('PERSON')

convert(df_data, filename)

df_data
# Out:
#         SBP   QUET  AGE  SMK
# PERSON
# 1       135  2.876   45    0
# 2       122  3.251   41    0
# 3       130  3.100   49    0
# 4       148  3.768   52    0
# 5       146  2.979   54    1
# 6       129  2.790   47    1
# 7       162  3.668   60    1
# 8       160  3.612   48    1
# 9       144  2.368   44    1
# 10      180  4.637   64    1
# 11      166  3.877   59    1
# 12      138  4.032   51    1
# 13      152  4.116   64    0
# 14      138  3.673   56    0
# 15      140  3.562   54    1
# 16      134  2.998   50    1
# 17      145  3.360   49    1
# 18      142  3.024   46    1
# 19      135  3.171   57    0
# 20      142  3.401   56    0
# 21      150  3.628   56    1
# 22      144  3.751   58    0
# 23      137  3.296   53    0
# 24      132  3.210   50    0
# 25      149  3.301   54    1
# 26      132  3.017   48    1
# 27      120  2.789   43    0
# 28      126  2.956   43    1
# 29      161  3.800   63    0
# 30      170  4.132   63    1
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PERSON  32 non-null     int64
#  1   SBP     32 non-null     int64
#  2   QUET    32 non-null     float64
#  3   AGE     32 non-null     int64
#  4   SMK     32 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 1.4 KB

# %%
df_data.describe()
# Out:
#           PERSON         SBP       QUET        AGE        SMK
# count  32.000000   32.000000  32.000000  32.000000  32.000000
# mean   16.500000  144.531250   3.441094  53.250000   0.531250
# std     9.380832   14.397545   0.497078   6.956083   0.507007
# min     1.000000  120.000000   2.368000  41.000000   0.000000
# 25%     8.750000  134.750000   3.022250  48.000000   0.000000
# 50%    16.500000  143.000000   3.380500  53.500000   1.000000
# 75%    24.250000  152.000000   3.776000  58.250000   1.000000
# max    32.000000  180.000000   4.637000  65.000000   1.000000
